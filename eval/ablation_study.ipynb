# %% [markdown]
# # KAIRA: Meaning Function Ablation Study
#
# This notebook reproduces the ablation study (Table 4) from the paper *KAIRA: A Control-Theoretic Framework for Stabilizing Stochastic Intelligence*.
# We isolate the impact of the Semantic Alignment Score (SAS), Emotional Coherence Score (ECS), Context Retention Score (CRS), and the dominant constraint: Ontological Consistency Score (OCS).

# %%
import sys
sys.path.append('../src')
from idl_engine import InternalDeliberationLoop, MeaningFunction, OntologyGraph
from run_experiment import simulate_ablation_study

# Execute the reference ablation sweep
simulate_ablation_study()

# %% [markdown]
# ### Conclusion
# As shown in the output, disabling ECS or CRS causes a negligible degradation in boundary control (1.8% -> 1.9% / 2.1%). However, removing OCS results in a catastrophic failure cascade (11.2% hallucination escape rate), confirming that the graph-topological boundary is the primary stabilization mechanism of the architecture.
